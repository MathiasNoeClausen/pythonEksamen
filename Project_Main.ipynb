# %% [markdown]
# ## david

# %%
from py_files.Plot_rating import plot_rating, plot_red, plot_white, plot_sparkling
import pandas as pd
# Out:
#                              Name    Year    Price  Rating  Reviews  \
# 0       Edizione Cinque Autoctoni  9999.0   149.00     4.3  57775.0
# 1                     Malbec 2016  2016.0    69.95     3.6  16818.0
# 2                     Malbec 2018  2018.0    59.95     3.8  16779.0
# 3                     Malbec 2016  2016.0   129.95     4.1  16138.0
# 4         Cabernet Sauvignon 2016  2016.0  1245.00     4.6  13945.0
# ...                           ...     ...      ...     ...      ...
# 3749             Sassoalloro 2015  2015.0   305.00     3.9   4157.0
# 3750              Pinot Noir 2019  2019.0    99.00     4.0   4156.0
# 3751     Tres Picos Garnacha 2016  2016.0   375.00     4.0   4147.0
# 3752   Scaia Rosso (Corvina) 2015  2015.0   112.50     3.8   4022.0
# 3753  Pinot Grigio Valdadige 2016  2016.0   135.00     3.8   3981.0
#
#             Country
# 0             Italy
# 1         Argentina
# 2         Argentina
# 3         Argentina
# 4     United States
# ...             ...
# 3749          Italy
# 3750  United States
# 3751          Spain
# 3752          Italy
# 3753          Italy
#
# [1048 rows x 6 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3754 entries, 0 to 3753
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  3751 non-null   object
#  1   Rating   3751 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 58.8+ KB

# %%
#plot_rating() viser min, median og max ratings på forskellige lande, samt information om lavest/højest rated vine
df1 = pd.read_csv('vinData.csv')
plot_rating(df1)
# Out:
# Lowest rated:                         Name    Year  Price  Rating  Reviews Country
# 736  Noble Dragon 张裕解百纳 2013  2013.0   89.0     2.8   1040.0   China
#
# Highest rated:                                             Name    Year  Price  Rating  \
# 1555  Adrianna Vineyard River Stones Malbec 2015  2015.0  795.0     4.8
#
#       Reviews    Country
# 1555    410.0  Argentina

# %%
redwine = pd.read_csv('redwinedata.csv', names=["Name", "Year", "Price", "Rating", "Reviews", "Country"])
whitewine = pd.read_csv('whitewinedata.csv', names=["Name", "Year", "Price", "Rating", "Reviews", "Country"])
sparklingwine = pd.read_csv('sparklingwinedata.csv', names=["Name", "Year", "Price", "Rating", "Reviews", "Country"])
#plot_rating(redwine)
#plot_rating(whitewine)
#plot_rating(sparklingwine)

# %%
# %pylab inline 
from py_files.Wine_Notes_Med_3d import get_appended_df, create_3d_plot, create_predicted_3d_plot, plot_mean_notes_for_countries, plot_mean_notes_for_winetypes

# %% [markdown]
# ## 3d

# %%
appended_df = get_appended_df()

# %%
create_3d_plot(appended_df)

# %%
create_predicted_3d_plot(appended_df)

# %%
import pandas as pd

df = pd.read_csv('WhiteWineWithNotes.csv')
plot_mean_notes_for_countries(df)

# %%
plot_mean_notes_for_winetypes(appended_df)

# %% [markdown]
# ## mathias

# %%
from py_files.BestWineByYear import max_rating_df, plot_max_df, max_occurences

# %%
#Renser i datasettet for kun at få fat i den data, vi skal bruge. 
#Vin skal være fra før 2022 og have mere end 0 reviews for at indgå i vores dataframe.
#Derudover fjerner vi Price kolonnen, da den ikke er relevant i forhold til det vi søger efter.
year_review_mask = (df1['Year'] < 2022) & (df1['Reviews'] > 0)
dfClean = df1[year_review_mask]


data_chart = dfClean.drop(columns=('Price'))
data_chart.head()
# Out:
#                       Name    Year  Rating  Reviews        Country
# 1              Malbec 2016  2016.0     3.6  16818.0      Argentina
# 2              Malbec 2018  2018.0     3.8  16779.0      Argentina
# 3              Malbec 2016  2016.0     4.1  16138.0      Argentina
# 4  Cabernet Sauvignon 2016  2016.0     4.6  13945.0  United States
# 5              Malbec 2013  2013.0     3.9  13271.0      Argentina

# %%
#Test index på vin, for at sikre at de forskellige kolonner ikke er blandet sammen med max funktionen.
data_chart.loc[1924]
# Out:
# Name       Adrianna Vineyard River Stones Malbec 2013
# Year                                             2013
# Rating                                            4.5
# Reviews                                           304
# Country                                     Argentina
# Name: 1924, dtype: object

# %%
#Dette dataframe viser hvilke vine, der har haft de højeste ratings fra 1982-2020.
maxdf = max_rating_df(data_chart)
maxdf
# Out:
#                                                    Name    Year  Rating  \
# 1557                                Barolo Riserva 1982  1982.0     4.6
# 383                                Cos d'Estournel 1986  1986.0     4.4
# 818                Saint-Julien (Grand Cru Classé) 1995  1995.0     4.3
# 2080                              Lazzarito Barolo 1999  1999.0     4.4
# 1417                    Dominus (Christian Moueix) 2003  2003.0     4.5
# 2174                          Côte-Rôtie La Turque 2004  2004.0     4.6
# 1590                   Château d'Ampuis Côte-Rôtie 2005  2005.0     4.4
# 1398                   Alter Ego de Château Palmer 2005  2005.0     4.4
# 1636          Martha's Vineyard Cabernet Sauvignon 2006  2006.0     4.6
# 2063                          Barolo Sorì Ginestra 2007  2007.0     4.4
# 2157  De Bvris Amarone della Valpolicella Classico R...  2008.0     4.6
# 125                    Pauillac (Grand Cru Classé) 2009  2009.0     4.7
# 1447                     Malleolus de Sanchomartin 2010  2010.0     4.6
# 171                    Pauillac (Grand Cru Classé) 2010  2010.0     4.6
# 1980                                 Cirsion Rioja 2011  2011.0     4.6
# 1450          Martha's Vineyard Cabernet Sauvignon 2012  2012.0     4.5
# 1809                            Vürsù Barolo Campè 2012  2012.0     4.5
# 3727                Napa Valley Cabernet Sauvignon 2013  2013.0     4.5
# 1877       Adrianna Vineyard Fortuna Terrae Malbec 2013  2013.0     4.5
# 1924         Adrianna Vineyard River Stones Malbec 2013  2013.0     4.5
# 22                  Napa Valley Cabernet Sauvignon 2013  2013.0     4.5
# 1221                                    Relentless 2013  2013.0     4.5
# 212   Gran Enemigo Single Vineyard Agrelo Cabernet F...  2013.0     4.5
# 1669                                   Nico Malbec 2014  2014.0     4.6
# 292   Gran Enemigo Single Vineyard Chacayes Cabernet...  2014.0     4.6
# 1015                    Dominus (Christian Moueix) 2014  2014.0     4.6
# 135   Gran Enemigo Single Vineyard Agrelo Cabernet F...  2014.0     4.6
# 1555         Adrianna Vineyard River Stones Malbec 2015  2015.0     4.8
# 73    Gran Enemigo Single Vineyard Gualtallary Caber...  2016.0     4.7
# 892   Gran Enemigo Single Vineyard Agrelo Cabernet F...  2016.0     4.7
# 315           Special Selection Cabernet Sauvignon 2016  2016.0     4.7
# 1820                               Proprietary Red 2016  2016.0     4.7
# 3591                              Malbec Argentino 2017  2017.0     4.7
# 36                                Malbec Argentino 2017  2017.0     4.7
# 440                               Malbec Argentino 2017  2017.0     4.7
# 1378                         Nicolás Catena Zapata 2017  2017.0     4.7
# 1718                                Flor de Pingus 2018  2018.0     4.6
# 354                             Appassimento Rosso 2019  2019.0     4.3
# 1546                         Blas Muñoz Chardonnay 2019  2019.0     4.3
# 2046              Estate Vineyards Sauvignon Blanc 2020  2020.0     4.3
# 1715                                       Verdejo 2020  2020.0     4.3
#
#       Reviews        Country
# 1557    408.0          Italy
# 383    1136.0         France
# 818     916.0         France
# 2080    273.0          Italy
# 1417    463.0  United States
# 2174    255.0         France
# 1590    396.0         France
# 1398    471.0         France
# 1636    382.0  United States
# 2063    277.0          Italy
# 2157    258.0          Italy
# 125    2412.0         France
# 1447    453.0          Spain
# 171    2084.0         France
# 1980    292.0          Spain
# 1450    452.0  United States
# 1809    334.0          Italy
# 3727   5489.0  United States
# 1877    315.0      Argentina
# 1924    304.0      Argentina
# 22     5487.0  United States
# 1221    559.0  United States
# 212    1755.0      Argentina
# 1669    373.0      Argentina
# 292    1417.0      Argentina
# 1015    707.0  United States
# 135    2334.0      Argentina
# 1555    410.0      Argentina
# 73     3091.0      Argentina
# 892     823.0      Argentina
# 315    1336.0  United States
# 1820    332.0  United States
# 3591   4606.0      Argentina
# 36     4580.0      Argentina
# 440    4570.0      Argentina
# 1378    481.0      Argentina
# 1718    357.0          Spain
# 354    1228.0          Italy
# 1546    414.0          Spain
# 2046    279.0    New Zealand
# 1715    358.0          Spain

# %%
#Dette er et bar-chart der tager maxdf, som parameter for at visualisere dataframet. 
#Derudover viser det hvor mange reviews de enkelte vine, og man kan derfor se en sammenhæng mellem ratings og reviews. 
maxdfplot = plot_max_df(maxdf)
maxdfplot
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7f500c65dad0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f500c444990>)

# %%
#Viser hvilke lande der flest gange har haft den/en af de bedste vin for et bestemt år. 
max_occurences(maxdf)
# Out:
# Argentina        13
# United States     9
# France            7
# Italy             6
# Spain             5
# New Zealand       1
# Name: Country, dtype: int64
